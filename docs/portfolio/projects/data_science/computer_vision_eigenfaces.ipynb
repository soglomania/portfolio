# %% [markdown]
# # tag
#
# data_science
#
# # title
#
# CV Eigenfaces
#
# # icon
#
# face_detection.png
#
# # summary_en
#
# This project was done as part of my image analysis module at ENSSAT. The goal is to implement a computer vision system to recognize people faces using the « eigenfaces » approach.
#
# # summary_fr
#
# Dans le cadre de ma formation d'ingénieur à l'ENSSAT, j'ai été amené à réaliser un projet sur le traitement et analyse d’image. Le projet consiste à proposer un système de reconnaissance automatique de visage basée sur l’approche « eigenfaces ».
#
#
# # summary_es
#
# El proyecto consiste en crear un sistema que analiza las imagenes para detectar las caras de las personas. El sistema fue creado usando el algoritmo de los « eigenfaces ».
#
# # description_en
#
#     ## Context
#
#     This project was done as part of my image analysis module at ENSSAT. The goal is to implement a computer vision system to recognize people faces using the « eigenfaces » approach.
#
#     The system should  :
#
#     * Allow to recognize a picture of size (56x46) pixels representing a face
#     * Identify a face in a video
#     * Be developped in scilab
#
#     ## Results
#
#     * [Project report](https://github.com/soglomania/eigenfaces/blob/master/docs/Rapport_final_Arcadius_SOGLO.pdf)
#     * [GitHub source code](https://github.com/soglomania/eigenfaces)
#
#
# # description_fr
#
#     ## Contexte
#
#     Dans le cadre de ma formation d'ingénieur, j'ai été amené à réaliser un projet sur le traitement et analyse d’image. Le projet consiste à proposer un système de reconnaissance automatique de visage basée sur l’approche « eigenfaces ».
#
#     Le système doit :
#
#     * Permettre de reconnaître une image de taille normalisée (56x46) pixels comme représentante d’un visage
#     * Permettre la reconnaissance d’un individu donné par son visage si ce dernier a été répertorié au préalable dans une base d’images (à mettre en place)
#     * Si possible permettre la reconnaissance d’un individu par son visage dans une image de plus grande taille (p.ex. 256 x 256)
#     * Si possible permettre le suivi temporel du visage d’un individu dans une séquence vidéo
#     * Etre développé en Scilab.
#
#     ## Résultats obtenus
#
#     * [Rapport de projet ](https://github.com/soglomania/eigenfaces/blob/master/docs/Rapport_final_Arcadius_SOGLO.pdf)
#     * [Github Code source](https://github.com/soglomania/eigenfaces)
#
#
# # description_es
#
#     ## Contexto
#
#     El proyecto consiste en crear un sistema que analiza las imagenes para detectar las caras de las personas. El sistema fue creado usando el algoritmo de los « eigenfaces ».
#
#     El sistema debe :
#
#     * Reconocer la cara de una persona en una foto de tamano (56x46) pixels
#     * Reconocer una cara en un video
#     * Programmado en scilab
#
#     ## Resultados obtenidos
#
#     * [Reporte del proyecto](https://github.com/soglomania/eigenfaces/blob/master/docs/Rapport_final_Arcadius_SOGLO.pdf)
#     * [Github codigo fuente](https://github.com/soglomania/eigenfaces)

# %% [markdown]
# # tag
#
# data_science
#
# # title
#
# Machine Learning with WEKA
#
# # icon
#
# weka.png
#
# # summary_en
#
# In the machine learning module during my Erasmus exchange at DIT we put in practice machine learning algorithms using WEKA.
#
# # summary_fr
#
# Dans le cadre du module Machine Learning à l'Institut technologique de Dublin (DIT), Ireland, j'ai mis en oeuvre mes connaissances sur les différents algorithmes étudiés en utilisant WEKA.
#
# # summary_es
#
# Durante mi intercambio Erasmus en DIT, Ireland, Los proyectos de Inteligencia Artificial fueron con WEKA.
#
# # description_en
#
#     ## Context
#
#     In the machine learning module during my Erasmus exchange at DIT we put in practice machine learning algorithms using WEKA. WEKA is a Machine learning/data mining software written in Java (distributed under the GNU Public License). It is used for research, education, and applications.
#
#     The different projects consist of using WEKA for preprocessing, modeling and evaluation.
#
#     # Results
#
#     * [Lab 1 report](https://www.dropbox.com/s/lwouqofv5e574za/Lab_1_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Lab 2 report](https://www.dropbox.com/s/0h609lfwg75kpjn/Lab_2_At_Home_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Lab 3 report](https://www.dropbox.com/s/6jy3ieb3k6kfi2y/Lab_3_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Lab 4 report](https://www.dropbox.com/s/ukms2dyu0gwions/Deliverable_Lab4_D17123407_Arcadius_SOGLO.zip?dl=0)
#     * [Assignment 1 report](https://www.dropbox.com/s/ccl3bw6ewhxh8tb/ML_Assignment_1_D17123407_Arcadius_SOGLO.docx?dl=0)
#     * [Assignment 2 report]()
#
#
# # description_fr
#
#     ## Contexte
#
#     Dans le cadre du module Machine Learning à l'Institut technologique de Dublin (DIT), Ireland, j'ai mis en oeuvre mes connaissances sur les différents algorithmes étudiés en utilisant WEKA. WEKA est un logiciel d'apprentissage machine / data mining écrit en Java (distribué sous licence publique GNU). Il est utilisé pour la recherche, l'éducation et les applications.
#
#     Les différents projets du module consiste à utilisé WEKA pour la préparation des données, la modélisation et l'évaluation.
#
#     ## Résultats obtenus
#
#     * [Rapport Lab 1](https://www.dropbox.com/s/lwouqofv5e574za/Lab_1_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Rapport Lab 2](https://www.dropbox.com/s/0h609lfwg75kpjn/Lab_2_At_Home_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Rapport Lab 3](https://www.dropbox.com/s/6jy3ieb3k6kfi2y/Lab_3_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Rapport Lab 4](https://www.dropbox.com/s/ukms2dyu0gwions/Deliverable_Lab4_D17123407_Arcadius_SOGLO.zip?dl=0)
#     * [Rapport Projet 1](https://www.dropbox.com/s/ccl3bw6ewhxh8tb/ML_Assignment_1_D17123407_Arcadius_SOGLO.docx?dl=0)
#     * [Rapport projet 2]()
#
#
#
# # description_es
#
#     ## Contexto
#
#     Durante mi intercambio Erasmus en DIT los proyectos de la asignatura Inteligencia Artificial fueron con WEKA. WEKA es un software de data mining/IA escrito en Java (distribuido bajo la Licencia Pública GNU). Se usa para la investigación, educación y las aplicaciones.
#
#     Los diferentes proyectos consistieron en usar WEKA para practicar las diferentes tecnicas de inteligencia artificial (Preparacion de los datos, Evaluacion)
#
#     ## Resultados obtenidos
#
#     * [Lab 1](https://www.dropbox.com/s/lwouqofv5e574za/Lab_1_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Lab 2](https://www.dropbox.com/s/0h609lfwg75kpjn/Lab_2_At_Home_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Lab 3](https://www.dropbox.com/s/6jy3ieb3k6kfi2y/Lab_3_Arcadius_SOGLO_D17123407.pdf?dl=0)
#     * [Lab 4](https://www.dropbox.com/s/ukms2dyu0gwions/Deliverable_Lab4_D17123407_Arcadius_SOGLO.zip?dl=0)
#     * [Proyecto 1](https://www.dropbox.com/s/ccl3bw6ewhxh8tb/ML_Assignment_1_D17123407_Arcadius_SOGLO.docx?dl=0)
#     * [Proyecto 2]()
